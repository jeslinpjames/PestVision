# %%
import cv2
import numpy as np
from ultralytics import YOLO
from PIL import Image, ImageDraw, ImageFont

def process_segments(image, model, segment_size):
    height, width, _ = image.shape
    results_list = []

    for y in range(0, height, segment_size):
        for x in range(0, width, segment_size):
            # Extract the segment
            segment = image[y:y+segment_size, x:x+segment_size]

            # Pad the segment if it's at the edge
            padded_segment = np.zeros((segment_size, segment_size, 3), dtype=np.uint8)
            padded_segment[:segment.shape[0], :segment.shape[1]] = segment

            # Run YOLO model on the segment
            results = model(padded_segment)
            results_list.append((results, x, y))

    return results_list

def annotate_image(image, results_list, segment_size):
    draw = ImageDraw.Draw(image)
    font = ImageFont.load_default()

    for results, x_offset, y_offset in results_list:
        for result in results:
            for box in result.boxes:
                xyxy = box.xyxy.squeeze().tolist()  # Ensure the coordinates are in a list format
                xmin, ymin, xmax, ymax = xyxy
                class_id = int(box.cls.squeeze().item())
                confidence = box.conf.squeeze().item()

                # Adjust coordinates with the offset
                xmin += x_offset
                ymin += y_offset
                xmax += x_offset
                ymax += y_offset

                # Draw bounding box and label
                draw.rectangle([xmin, ymin, xmax, ymax], outline="red", width=2)
                label = f"{class_id}: {confidence:.2f}"
                draw.text((xmin, ymin), label, fill="red", font=font)

    return image

def main(image_path, model_path, output_path, segment_size=1080):
    # Load the YOLO model
    model = YOLO(model_path)

    # Load the high-resolution image
    image = cv2.imread(image_path)
    height, width, _ = image.shape

    # Process image segments
    results_list = process_segments(image, model, segment_size)

    # Create a PIL image for annotation
    pil_image = Image.fromarray(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

    # Annotate the image
    annotated_image = annotate_image(pil_image, results_list, segment_size)

    # Save the final annotated image
    annotated_image.save(output_path)
    annotated_image.show()

# Define paths and parameters
image_path = "D:/git/New folder/data/val/images/2a0df4a2-7398-4f0b-ab3f-02e8e84fe60f.jpg"
model_path = "C:/Users/jesli/Downloads/train8/weights/best.pt"
output_path = "annotated_output_image.jpg"

# Run the main function
main(image_path, model_path, output_path)
# Out:
# 0: 640x640 (no detections), 83.9ms
# Speed: 6.2ms preprocess, 83.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 84.1ms
# Speed: 6.3ms preprocess, 84.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 54.6ms
# Speed: 0.7ms preprocess, 54.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 26.1ms
# Speed: 9.3ms preprocess, 26.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 21.4ms
# Speed: 6.6ms preprocess, 21.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 21.0ms
# Speed: 4.2ms preprocess, 21.0ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 27.4ms
# Speed: 6.9ms preprocess, 27.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 pests, 27.7ms
# Speed: 6.9ms preprocess, 27.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 29.7ms
# Speed: 2.0ms preprocess, 29.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 pests, 25.2ms
# Speed: 4.1ms preprocess, 25.2ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 27.2ms
# Speed: 6.7ms preprocess, 27.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 pests, 36.0ms
# Speed: 0.0ms preprocess, 36.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 20.9ms
# Speed: 5.0ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 pests, 19.1ms
# Speed: 5.0ms preprocess, 19.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 30.9ms
# Speed: 0.0ms preprocess, 30.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 31.9ms
# Speed: 0.0ms preprocess, 31.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 27.4ms
# Speed: 0.9ms preprocess, 27.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 33.6ms
# Speed: 0.0ms preprocess, 33.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 35.2ms
# Speed: 0.0ms preprocess, 35.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 pests, 28.0ms
# Speed: 7.3ms preprocess, 28.0ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 pests, 24.4ms
# Speed: 4.0ms preprocess, 24.4ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 27.0ms
# Speed: 7.5ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 27.9ms
# Speed: 0.0ms preprocess, 27.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 27.6ms
# Speed: 10.0ms preprocess, 27.6ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 27.1ms
# Speed: 3.5ms preprocess, 27.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 pests, 27.8ms
# Speed: 7.0ms preprocess, 27.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 pests, 30.2ms
# Speed: 7.0ms preprocess, 30.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 27.9ms
# Speed: 0.0ms preprocess, 27.9ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 20.3ms
# Speed: 3.5ms preprocess, 20.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.2ms
# Speed: 0.0ms preprocess, 25.2ms inference, 9.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 35.6ms
# Speed: 0.0ms preprocess, 35.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 pests, 21.1ms
# Speed: 3.9ms preprocess, 21.1ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 26.5ms
# Speed: 7.9ms preprocess, 26.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 24.5ms
# Speed: 10.0ms preprocess, 24.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 27.1ms
# Speed: 10.4ms preprocess, 27.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 24.4ms
# Speed: 3.0ms preprocess, 24.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 20.5ms
# Speed: 3.5ms preprocess, 20.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 33.6ms
# Speed: 0.0ms preprocess, 33.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 27.7ms
# Speed: 0.8ms preprocess, 27.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 21.3ms
# Speed: 4.5ms preprocess, 21.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 27.9ms
# Speed: 0.0ms preprocess, 27.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 27.2ms
# Speed: 10.9ms preprocess, 27.2ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 30.1ms
# Speed: 1.5ms preprocess, 30.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 27.1ms
# Speed: 3.0ms preprocess, 27.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 31.8ms
# Speed: 0.0ms preprocess, 31.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 30.4ms
# Speed: 0.0ms preprocess, 30.4ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 27.0ms
# Speed: 3.8ms preprocess, 27.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2
from ultralytics import YOLO
from PIL import Image

# Define paths and parameters
image_path = "D:/git/Data/PestVisionEvalImages/Data/val/images/2a0df4a2-7398-4f0b-ab3f-02e8e84fe60f.jpg"
model_path = "C:/Users/james/Downloads/ip102_sythetic train 1st try/weights/best.pt"
output_path = "output_image.jpg"

# Load the YOLO model
model = YOLO(model_path)

# Load the high-resolution image
image = cv2.imread(image_path)

# Make predictions using the YOLO model
results = model(image)

# Draw bounding boxes on the image
annotated_img = results[0].plot()

# Convert to PIL Image
pil_img = Image.fromarray(cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB))

# Save the annotated image
pil_img.save(output_path)

print(f"Annotated image saved to {output_path}")
# Out:
# 0: 640x480 1 pest, 1215.0ms
# Speed: 19.0ms preprocess, 1215.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Annotated image saved to output_image.jpg

# %%
import cv2
import numpy as np
from ultralytics import YOLO
from PIL import Image, ImageDraw
import os

def process_segments(image, model, segment_size):
    height, width, _ = image.shape
    results_list = []

    for y in range(0, height, segment_size):
        for x in range(0, width, segment_size):
            # Extract the segment
            segment = image[y:y+segment_size, x:x+segment_size]

            # Pad the segment if it's at the edge
            padded_segment = np.zeros((segment_size, segment_size, 3), dtype=np.uint8)
            padded_segment[:segment.shape[0], :segment.shape[1]] = segment

            # Run YOLO model on the segment
            results = model(padded_segment)
            results_list.append((results, x, y))

    return results_list

def annotate_image(image, results_list, segment_size):
    draw = ImageDraw.Draw(image)

    for results, x_offset, y_offset in results_list:
        for result in results:
            for box in result.boxes:
                xyxy = box.xyxy.squeeze().tolist()  # Ensure the coordinates are in a list format
                xmin, ymin, xmax, ymax = xyxy
                class_id = int(box.cls.squeeze().item())

                # Adjust coordinates with the offset
                xmin += x_offset
                ymin += y_offset
                xmax += x_offset
                ymax += y_offset

                # Draw bounding box and label
                draw.rectangle([xmin, ymin, xmax, ymax], outline="red", width=2)
                draw.text((xmin, ymin), str(class_id), fill="red")

    return image

def process_images_from_directory(directory_path, model_path, output_dir, x, segment_size=640):
    # Load the YOLO model
    model = YOLO(model_path)

    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Get the first x image filenames
    image_files = [f for f in os.listdir(directory_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))][:x]

    for filename in image_files:
        image_path = os.path.join(directory_path, filename)
        output_path = os.path.join(output_dir, filename)

        # Load the high-resolution image
        image = cv2.imread(image_path)

        # Process image segments
        results_list = process_segments(image, model, segment_size)

        # Create a PIL image for annotation
        pil_image = Image.fromarray(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

        # Annotate the image
        annotated_image = annotate_image(pil_image, results_list, segment_size)

        # Save the final annotated image
        annotated_image.save(output_path)
        print(f"Annotated image saved to {output_path}")

# Define paths and parameters
directory_path = "D:/git/Data/PestVisionEvalImages/Data/val/images"
model_path = "C:/Users/james/Downloads/ip102_sythetic train 1st try/weights/best.pt"
output_dir = "annotated_output_images"
x = 30 # Number of images to process

# Run the main function
process_images_from_directory(directory_path, model_path, output_dir, x)
# Out:
# 0: 640x640 (no detections), 2201.6ms
# Speed: 51.1ms preprocess, 2201.6ms inference, 31.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1829.1ms
# Speed: 16.1ms preprocess, 1829.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1802.1ms
# Speed: 0.0ms preprocess, 1802.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1884.6ms
# Speed: 9.1ms preprocess, 1884.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1878.8ms
# Speed: 0.0ms preprocess, 1878.8ms inference, 32.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1784.9ms
# Speed: 0.0ms preprocess, 1784.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1792.6ms
# Speed: 22.7ms preprocess, 1792.6ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1719.5ms
# Speed: 0.0ms preprocess, 1719.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1935.6ms
# Speed: 0.0ms preprocess, 1935.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 2254.7ms
# Speed: 1.8ms preprocess, 2254.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1753.0ms
# Speed: 9.9ms preprocess, 1753.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1744.3ms
# Speed: 0.0ms preprocess, 1744.3ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1814.8ms
# Speed: 0.0ms preprocess, 1814.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1605.7ms
# Speed: 7.0ms preprocess, 1605.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1676.5ms
# Speed: 15.7ms preprocess, 1676.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1929.8ms
# Speed: 9.2ms preprocess, 1929.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1604.3ms
# Speed: 15.6ms preprocess, 1604.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1896.2ms
# Speed: 0.0ms preprocess, 1896.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1999.6ms
# Speed: 3.4ms preprocess, 1999.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1740.6ms
# Speed: 0.0ms preprocess, 1740.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1888.1ms
# Speed: 7.9ms preprocess, 1888.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Annotated image saved to annotated_output_images\003b31de-06e2-4ff9-a120-3bd8014ee166.jpg
#
# 0: 640x640 (no detections), 1831.6ms
# Speed: 0.0ms preprocess, 1831.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 2251.6ms
# Speed: 0.0ms preprocess, 2251.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1782.1ms
# Speed: 7.1ms preprocess, 1782.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1858.5ms
# Speed: 12.0ms preprocess, 1858.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1822.8ms
# Speed: 6.3ms preprocess, 1822.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1785.7ms
# Speed: 6.3ms preprocess, 1785.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Annotated image saved to annotated_output_images\00957121-d626-4b67-9aa8-5d5efebb6884.jpg
#
# 0: 640x640 1 pest, 2174.2ms
# Speed: 8.1ms preprocess, 2174.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1616.1ms
# Speed: 11.0ms preprocess, 1616.1ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1719.6ms
# Speed: 13.4ms preprocess, 1719.6ms inference, 9.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1716.3ms
# Speed: 0.0ms preprocess, 1716.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1801.3ms
# Speed: 12.9ms preprocess, 1801.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1552.4ms
# Speed: 2.8ms preprocess, 1552.4ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 640)
# Annotated image saved to annotated_output_images\00dc2285-26d5-406d-9632-b867fbb84adc.jpg
#
# 0: 640x640 1 pest, 1658.9ms
# Speed: 6.6ms preprocess, 1658.9ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1908.3ms
# Speed: 4.2ms preprocess, 1908.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1605.2ms
# Speed: 11.0ms preprocess, 1605.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1620.5ms
# Speed: 5.9ms preprocess, 1620.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 2014.3ms
# Speed: 3.9ms preprocess, 2014.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 
ms inference, 15.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1820.2ms
# Speed: 0.0ms preprocess, 1820.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1820.4ms
# Speed: 8.1ms preprocess, 1820.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1873.8ms
# Speed: 0.0ms preprocess, 1873.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1912.3ms
# Speed: 11.3ms preprocess, 1912.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1854.3ms
# Speed: 0.0ms preprocess, 1854.3ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1891.6ms
# Speed: 8.9ms preprocess, 1891.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1841.9ms
# Speed: 15.7ms preprocess, 1841.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1923.7ms
# Speed: 0.0ms preprocess, 1923.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 pests, 1986.5ms
# Speed: 15.7ms preprocess, 1986.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1859.9ms
# Speed: 0.0ms preprocess, 1859.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 pests, 1795.6ms
# Speed: 15.6ms preprocess, 1795.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2215.2ms
# Speed: 0.0ms preprocess, 2215.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Annotated image saved to annotated_output_images\05d170db-ceca-4fdc-933a-fe9211bd69e6.jpg
#
# 0: 640x640 1 pest, 1826.6ms
# Speed: 5.9ms preprocess, 1826.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1810.4ms
# Speed: 15.7ms preprocess, 1810.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 pests, 1892.1ms
# Speed: 0.0ms preprocess, 1892.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1766.1ms
# Speed: 15.6ms preprocess, 1766.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Annotated image saved to annotated_output_images\05e0321b-af70-4aba-96ee-5c86c2085b1e.jpg
#
# 0: 640x640 (no detections), 1798.8ms
# Speed: 6.6ms preprocess, 1798.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1705.7ms
# Speed: 5.3ms preprocess, 1705.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 pests, 1779.6ms
# Speed: 15.7ms preprocess, 1779.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1748.3ms
# Speed: 15.7ms preprocess, 1748.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1707.6ms
# Speed: 15.6ms preprocess, 1707.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1772.2ms
# Speed: 0.0ms preprocess, 1772.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1809.5ms
# Speed: 0.0ms preprocess, 1809.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 pests, 2014.1ms
# Speed: 6.0ms preprocess, 2014.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1884.4ms
# Speed: 14.6ms preprocess, 1884.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1937.1ms
# Speed: 0.0ms preprocess, 1937.1ms inference, 15.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2056.8ms
# Speed: 0.0ms preprocess, 2056.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pest, 1905.8ms
# Speed: 11.2ms preprocess, 1905.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1887.2ms
# Speed: 0.0ms preprocess, 1887.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1827.4ms
# Speed: 0.0ms preprocess, 1827.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1828.2ms
# Speed: 6.5ms preprocess, 1828.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1832.9ms
# Speed: 6.3ms preprocess, 1832.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1852.1ms
# Speed: 8.1ms preprocess, 1852.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1843.9ms
# Speed: 15.6ms preprocess, 1843.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1874.3ms
# Speed: 0.0ms preprocess, 1874.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1865.1ms
# Speed: 9.2ms preprocess, 1865.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2041.1ms
# Speed: 8.8ms preprocess, 2041.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Annotated image saved to annotated_output_images\061b2c3c-2991-426f-98ba-a90d11d7a6d0.jpg

# %%
from ultralytics import YOLO

def evaluate_model_performance(model_path, data_path):
    # Load the trained model
    model = YOLO(model_path)

    # Evaluate the model on the evaluation data
    results = model.val(data=data_path)

    # Print the results
    print("Evaluation Results:")
    print(results)

# Define model path and evaluation data path
model_path = "C:/Users/jesli/Downloads/train4/weights/best.pt"
data_path = "config2.yaml"

# Evaluate the model performance
evaluate_model_performance(model_path, data_path)
# Out:
# Ultralytics YOLOv8.2.16  Python-3.12.3 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# c:\Users\jesli\anaconda3\envs\pv\Lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ..\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# YOLOv5m summary (fused): 248 layers, 25045795 parameters, 0 gradients, 64.0 GFLOPs
# val: Scanning D:\git\New folder\data\val\labels.cache... 865 images, 87 backgrounds, 0 corrupt: 100%|██████████| 865/865 [00:00<?, ?it/s]
